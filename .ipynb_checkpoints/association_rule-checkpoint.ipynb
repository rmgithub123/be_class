# %%
# !pip install mlxtend
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
#from mlxtend.preprocessing
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.5 MB/s eta 0:00:000:00:010:00:01:01
# ...
#   Obtaining dependency information for scipy>=1.2.1 from https://files.pythonhosted.org/packages/a8/cc/c36f3439f5d47c3b13833ce6687b43a040cc7638c502ac46b41e2d4f3d6f/scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 983.7 kB/s eta 0:00:0031m5.2 MB/s eta 0:00:01
# ...
#   Obtaining dependency information for scikit-learn>=1.0.2 from https://files.pythonhosted.org/packages/5c/e9/ee572691a3fb05555bcde41826faad29ae4bc1fb07982e7f53d54a176879/scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for joblib>=0.13.2 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
#from mlxtend.preprocessing

# %%
titanic = pd.read_csv("/home/madhuri/Downloads/Titanic.csv")

# %%
titanic.head()
# Out:
#   Class Gender    Age Survived
# 0   3rd   Male  Child       No
# 1   3rd   Male  Child       No
# 2   3rd   Male  Child       No
# 3   3rd   Male  Child       No
# 4   3rd   Male  Child       No

# %%
# preprocessing

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2201 entries, 0 to 2200
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Class     2201 non-null   object
#  1   Gender    2201 non-null   object
#  2   Age       2201 non-null   object
#  3   Survived  2201 non-null   object
# dtypes: object(4)
# memory usage: 68.9+ KB

# %%
df= pd.get_dummies(titanic)

# %%
df
# Out:
#       Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  Gender_Male  \
# 0         False      False       True       False          False         True
# 1         False      False       True       False          False         True
# 2         False      False       True       False          False         True
# 3         False      False       True       False          False         True
# 4         False      False       True       False          False         True
# ...         ...        ...        ...         ...            ...          ...
# 2196      False      False      False        True           True        False
# 2197      False      False      False        True           True        False
# 2198      False      False      False        True           True        False
# 2199      False      False      False        True           True        False
# 2200      False      False      False        True           True        False
#
# ...

# %%
## Apriori algo

# %%
frequent_items = apriori(df,min_support=0.6,use_colnames = True)
frequent_items
# Out:
#     support                               itemsets
# 0  0.786461                          (Gender_Male)
# 1  0.950477                            (Age_Adult)
# 2  0.676965                          (Survived_No)
# 3  0.757383               (Gender_Male, Age_Adult)
# 4  0.619718             (Gender_Male, Survived_No)
# 5  0.653339               (Age_Adult, Survived_No)
# 6  0.603816  (Gender_Male, Age_Adult, Survived_No)

# %%
#RUles

# %%
rules = association_rules(frequent_items,metric="lift" , min_threshold=1)

# %%
rules
# Out:
#                    antecedents                 consequents  \
# 0                (Gender_Male)                 (Age_Adult)
# 1                  (Age_Adult)               (Gender_Male)
# 2                (Gender_Male)               (Survived_No)
# 3                (Survived_No)               (Gender_Male)
# 4                  (Age_Adult)               (Survived_No)
# 5                (Survived_No)                 (Age_Adult)
# 6     (Gender_Male, Age_Adult)               (Survived_No)
# 7   (Gender_Male, Survived_No)                 (Age_Adult)
# 8     (Age_Adult, Survived_No)               (Gender_Male)
# 9                (Gender_Male)    (Age_Adult, Survived_No)
# 10                 (Age_Adult)  (Gender_Male, Survived_No)
# 11               (Survived_No)    (Gender_Male, Age_Adult)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.786461            0.950477  0.757383    0.963027  1.013204
# ...

# %%
rules.sort_values('lift',ascending=False)[0:10]
# Out:
#                    antecedents                 consequents  \
# 6     (Gender_Male, Age_Adult)               (Survived_No)
# 11               (Survived_No)    (Gender_Male, Age_Adult)
# 8     (Age_Adult, Survived_No)               (Gender_Male)
# 9                (Gender_Male)    (Age_Adult, Survived_No)
# 2                (Gender_Male)               (Survived_No)
# 3                (Survived_No)               (Gender_Male)
# 7   (Gender_Male, Survived_No)                 (Age_Adult)
# 10                 (Age_Adult)  (Gender_Male, Survived_No)
# 4                  (Age_Adult)               (Survived_No)
# 5                (Survived_No)                 (Age_Adult)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 6             0.757383            0.676965  0.603816    0.797241  1.177669
# 11            0.676965            0.757383  0.603816    0.891946  1.177669
# 8             0.653339            0.786461  0.603816    0.924200  1.175139
# ...
