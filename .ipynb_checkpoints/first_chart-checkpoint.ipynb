# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 2.2 MB/s eta 0:00:002.2 MB/s eta 0:00:01
# ...

# %%
import seaborn as sns

# %%
tips = pd.read_csv("/home/madhuri/ds_venv/mr_venv/be_class/streamline/tips.csv")

# %% [raw]
# tips

# %%
new_c = pd.read_csv("/home/madhuri/Downloads/experiment.csv")

# %%
plt.subplot(1,2,1)
sns.lineplot(x='day',y='tip',data=tips)
plt.ylabel('tip $')
plt.subplot(1,2,2)
sns.violinplot(x='day',y='tip',data=tips)
plt.ylabel('tip $')

plt.show()

# %%
plt.subplot(1,2,1)
sns.lineplot(x='Months',y='Transport',data=new_c)
plt.ylabel('Transport')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.subplot(1,2,1)
# ----> 2 sns.lineplot(x='Months',y='Transport',data=new_c)
#       3 plt.ylabel('Transport')
#       4 plt.subplot(1,2,2)
#
# File ~/ds_venv/mr_venv/lib/python3.10/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
# ...

# %%
new_c
# Out:
#     Months   Transport  tra_per  ETA  eta_per  POD  pod_per
# 0   January        181       12   14       27   17       25
# 1  February        259       17    8       15    9       13
# 2     March        221       14    9       17   15       22
# 3     April        204       13    9       17    2        3
# 4       May        179       12    5       10    8       12
# 5      June        187       12    2        4    9       13
# 6      July        185       12    1        2    5        7
# 7    August        143        9    5       10    2        3

# %%
new_c = pd.read_csv("/home/madhuri/Downloads/experiment.csv")

# %%
new_c
# Out:
#      Months  Transport  tra_per  ETA  eta_per  POD  pod_per
# 0   January        181       12   14       27   17       25
# 1  February        259       17    8       15    9       13
# 2     March        221       14    9       17   15       22
# 3     April        204       13    9       17    2        3
# 4       May        179       12    5       10    8       12
# 5      June        187       12    2        4    9       13
# 6      July        185       12    1        2    5        7
# 7    August        143        9    5       10    2        3

# %%
plt.subplot(1,2,1)
sns.lineplot(x='Months',y='Transport',data=new_c)
plt.ylabel('Transport')
plt.subplot(1,2,2)
sns.lineplot(x='Months',y='tra_per',data=new_c)
plt.ylabel('Transport Percentage')

plt.show()

# %%
plt.subplot(1,2,1)
sns.lineplot(x='Months',y='Transport',data=new_c)
plt.ylabel('Transport')
plt.subplot(1,2,2)
sns.lineplot(x='Months',y='tra_per',data=new_c)
plt.ylabel('Transport Percentage')
plt.show()

# %%
new_c["Months"] = pd.Categorical(new_c["Months"])

# %%
sns.pairplot(new_c,hue="Months",diag_kind="kde")
# Out:
# /home/madhuri/ds_venv/mr_venv/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.show()
